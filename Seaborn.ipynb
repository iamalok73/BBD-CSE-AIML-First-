# %% [markdown]
# # Seaborn
#
# - Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
titanic = sns.load_dataset('titanic')
(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')
iris = sns.load_dataset('iris')
planets = sns.load_dataset('planets')

# %%
tips = sns.load_dataset('tips')

tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
print(plt.scatter(tips["tip"],tips["total_bill"]))
plt.show()
plt.title("Matplotlib")
print("----------------------------------------")

print(sns.scatterplot(x='tip', y='total_bill', data=tips))
# Out:
# ...
# ----------------------------------------
# Axes(0.125,0.11;0.775x0.77)

# %%
plt.scatter(tips["total_bill"],tips["tip"],)

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips,hue=tips['day'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day', size='size')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day', size='size', palette='YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # **HISTOGRAM**

# %%
sns.histplot(tips['tip'], bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'], bins=15, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # **DISTPLOT**

# %%
sns.distplot(tips['tip'], bins=15, kde=True)
# Out:
# C:\Users\AlokVerma\AppData\Local\Temp\ipykernel_4004\1617148543.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], bins=15, kde=True)
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # **BARPLOT**

# %%
sns.barplot(x='sex',y='tip', data=tips, palette='YlGnBu')
# Out:
# C:\Users\AlokVerma\AppData\Local\Temp\ipykernel_4004\2848788611.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='tip', data=tips, palette='YlGnBu')
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# # **BOXPLOT**

# %%
sns.boxplot(x='day',y='tip', data=tips, palette='YlGnBu')
# Out:
# C:\Users\AlokVerma\AppData\Local\Temp\ipykernel_4004\1010909403.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='tip', data=tips, palette='YlGnBu')
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **STRIPPLOT**

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **JOIN PLOT: SCATTER PLOT + DISTRIBUTION PLOT**

# %%
sns.jointplot(x='tip', y='total_bill', data=tips)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hist')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True)
# Out:
# C:\Users\AlokVerma\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True, cmap='YlGnBu') #cmap=color_map
# Out:
# C:\Users\AlokVerma\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hex',  cmap='YlGnBu') #kind=hex and no shade

# %% [markdown]
# # **PAIRPLOT**

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')

# %% [markdown]
# # **HEATMAP**

# %%
sns.heatmap(tips.corr(), cmap='YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sns.heatmap(tips.corr(), cmap='YlGnBu')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.heatmap(titanic.corr(), cmap='YlGnBu', annot=True) #cmap= coolwarm, icefire
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.heatmap(titanic.corr(), cmap='YlGnBu', annot=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# # **CLUSTERMAP**

# %%
sns.clustermap(iris.drop(['species'], axis=1))

# %%
import seaborn 
   
   
seaborn.set(style = 'whitegrid')  
tip = seaborn.load_dataset('tips')
 
seaborn.violinplot(x ='day', y ='tip', data = tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
