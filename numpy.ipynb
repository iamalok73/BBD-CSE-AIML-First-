# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.1.3

# %%
l = [1,2,3,4]
print(type(l))
print(l)
# Out:
# <class 'list'>
# [1, 2, 3, 4]

# %%
n = np.array([1,2,3,4])
print(type(n))
print(n)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4]

# %%
n = np.array([[1,2,3],[11,22,33],[77,65,44]])
print(type(n))
print(n)
# Out:
# <class 'numpy.ndarray'>
# [[ 1  2  3]
#  [11 22 33]
#  [77 65 44]]

# %%
n.shape
# Out:
# (3, 3)

# %%
n = np.array([[11,22,33],[77,65,44]])
print(type(n))
print(n)
# Out:
# <class 'numpy.ndarray'>
# [[11 22 33]
#  [77 65 44]]

# %%
n.shape
# Out:
# (2, 3)

# %%
print(n[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(n[2])
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
n = np.array([1,2,3,4])
print(type(n))
print(n)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4]

# %%
n[0] =2000

# %%
print(n)
# Out:
# [2000    2    3    4]

# %%
print(type(n))
# Out:
# <class 'numpy.ndarray'>

# %%
n[:2]
# Out:
# array([2000,    2])

# %%
print(n[:10])
# Out:
# [2000    2    3    4]

# %%
print(n[3:10])
# Out:
# [4]

# %%
n.shape
# Out:
# (4,)

# %%
n.size
# Out:
# 4

# %%
n.dtype
# Out:
# dtype('int64')

# %%
n.reshape(2,2)
# Out:
# array([[2000,    2],
#        [   3,    4]])
