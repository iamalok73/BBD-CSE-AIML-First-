# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import random
from skimage.util import random_noise
from skimage import transform
from cv2 import resize

# %%
# pip install opencv-python

# %%
img = mpimg.imread(r"C:\Users\AlokVerma\Desktop\image.jpg")

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
new_img = resize(img,(1500,1150))

# %%
plt.imshow(new_img)
plt.axis('off')
plt.show()

# %%
## flipping the image

# %%
hori = np.fliplr(img)
plt.imshow(hori)
plt.axis('off')
plt.show()

# %%
ver = np.flipud(img)
plt.imshow(ver)
plt.axis('off')
plt.show()

# %%
## Rotate the image.

# %%
from skimage import transform

# %%
new_rotate = transform.rotate(img,30)
plt.imshow(new_rotate)
plt.axis('off')
plt.show()

# %%
new_rotate = transform.rotate(img,random.uniform(-60,40))
plt.imshow(new_rotate)
plt.axis('off')
plt.show()

# %%
## Adding Noise

# %%
add_img = random_noise(img,mode='localvar',clip=True)
plt.imshow(add_img)
